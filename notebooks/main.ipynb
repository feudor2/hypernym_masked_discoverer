# %%
import os
import pickle
import pandas as pd

import yadisk
import zipfile
import nltk

from for_masked_lm import HypernymMaskedModel, ResultsWrapper
from vector_model import VectorModel
from prompt_utils import basic_prompts
# Out:
# /home/jupyter/.local/lib/python3.10/site-packages/transformers/utils/hub.py:124: FutureWarning: Using `TRANSFORMERS_CACHE` is deprecated and will be removed in v5 of Transformers. Use `HF_HOME` instead.
#   warnings.warn(

# %%
# loading dataset
with open('dataset.pickle', 'rb') as _:
    dataset = pickle.load(_)

# %%
dataset
# Out:
#                data  ...                  set
# 0     maliciousness  ...      1A.english.test
# 1           buckler  ...      1A.english.test
# 2         spelunker  ...      1A.english.test
# 3      quo warranto  ...      1A.english.test
# 4      Jeff Francis  ...      1A.english.test
# ...             ...  ...                  ...
# 3045  foreshadowing  ...  1A.english.training
# 3046     salamander  ...  1A.english.training
# 3047        praetor  ...  1A.english.training
# 3048   endocarditis  ...  1A.english.training
# 3049   Michael Owen  ...  1A.english.training
#
# [3050 rows x 4 columns]

# %%
# load vector model (fasttext)
y = yadisk.YaDisk()
filename = 'fasttext.zip'
url = 'https://disk.yandex.ru/d/dM3Vn2mlExzyZQ'
y.download_public(url, filename)
with zipfile.ZipFile(filename, 'r') as zip_ref:
    zip_ref.extractall()

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /home/jupyter/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
fasttext = VectorModel('fasttext/umbc_model_best.bin')

# %%
# alternatively, you can load already predicted candidates
with open('fasttext_predictions.pickle', 'rb') as _:
    preds = pickle.load(_)
dataset['pred'] = preds

# %%
# define the subset
subset_name = '1A.english.trial'
subset = dataset[dataset['set'] == subset_name]

# %%
#if you are using vector model, get predictions 
subset = fasttext.predict(subset, k=15, filter_=True, col_in='data', col_out='pred')

# %%
subset.head(3)
# Out:
#                       data     base  ...               set         pred
# 1500                dirham  Concept  ...  1A.english.trial          NaN
# 1501  sociology department  Concept  ...  1A.english.trial   department
# 1502           Burger King   Entity  ...  1A.english.trial  King,Burger
#
# [3 rows x 5 columns]

# %%
# loading model
model = HypernymMaskedModel(model_path="bert-base-cased", device='cpu')
with open('stopwords.pickle', 'rb') as _:
    STOPWORDS = pickle.load(_)
# Out:
# Some weights of the model checkpoint at bert-base-cased were not used when initializing BertForMaskedLM: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
# use model to get predictions
output = model.prediction_in_dataset(
        subset,
        hyper_prompts=basic_prompts['hyper_prompts'],
        cohypo_prompts=basic_prompts['best_cohypo_prompt'],
        mixed_prompts=basic_prompts['mixed_prompts'],
        candidates=subset['pred'],
        k_out=15,
        k_hyper=15,
        k_hypo=15,
        col_in='data',
        stopwords=STOPWORDS,
        article=(True, True, False),
        seed=42
)
# Out:
# 2it [02:20, 76.88s/it]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_15677/2282329513.py in <cell line: 2>()
#       1 # use model to get predictions
# ----> 2 output = model.prediction_in_dataset(
#       3         subset,
#       4         hyper_prompts=basic_prompts['hyper_prompts'],
#       5         cohypo_prompts=basic_prompts['best_cohypo_prompt'],
#
# ~/work/resources/repository/for_masked_lm.py in prediction_in_dataset(self, dataset, hyper_prompts, cohypo_prompts, mixed_prompts, candidates, k_out, k_hyper, k_hypo, col_in, stopwords, article, seed)
#     455         """
#     456         self.set_random_seed(seed)
# --> 457         tables = [
#     458             self.create_table_from_results(
#     459                 self.predict_iterative(
#
# ~/work/resources/repository/for_masked_lm.py in <listcomp>(.0)
#     457         tables = [
#     458             self.create_table_from_results(
# --> 459                 self.predict_iterative(
#     460                     w,
#     461                     hyper_prompts,
#
# ~/work/resources/repository/for_masked_lm.py in predict_iterative(self, word, hyper_prompts, cohypo_prompts, mixed_prompts, candidates, k_out, k_hyper, k_hypo, stopwords, article)
#     340             )
#     341             if candidates_cohypo != [[], []]:
# --> 342                 results_ft_cohypo = from_cohypo(candidates_cohypo)
#     343                 #print(candidates_cohypo, results_ft_cohypo, sep='\n')
#     344                 iter_ft_cohypo = iterative(word, results_ft_cohypo, hyper_prompts, '', MAX=1.0)
#
# ~/work/resources/repository/for_masked_lm.py in from_cohypo(cohypos)
#     251         def from_cohypo(cohypos):
#     252             '''A function to predict new hypernyms for discovered co-hyponyms'''
# --> 253             to_hyper = [[wn_filter(self.probable_words(prepare_prompts(c[0], hyper_prompts)[i], k=k_hyper, article=article[0]),
#     254                                    word=c[0], mode='single', stopwords=stopwords)
#     255                         for c in pr]
#
# ~/work/resources/repository/for_masked_lm.py in <listcomp>(.0)
#     251         def from_cohypo(cohypos):
#     252             '''A function to predict new hypernyms for discovered co-hyponyms'''
# --> 253             to_hyper = [[wn_filter(self.probable_words(prepare_prompts(c[0], hyper_prompts)[i], k=k_hyper, article=article[0]),
#     254                                    word=c[0], mode='single', stopwords=stopwords)
#     255                         for c in pr]
#
# ~/work/resources/repository/for_masked_lm.py in <listcomp>(.0)
#     251         def from_cohypo(cohypos):
#     252             '''A function to predict new hypernyms for discovered co-hyponyms'''
# --> 253             to_hyper = [[wn_filter(self.probable_words(prepare_prompts(c[0], hyper_prompts)[i], k=k_hyper, article=article[0]),
#     254                                    word=c[0], mode='single', stopwords=stopwords)
#     255                         for c in pr]
#
# TypeError: HypernymMaskedModel.probable_words() got an unexpected keyword argument 'article'

# %%
# unpack results
results = ResultsWrapper(subset, tables=output, col_in='data')
#results.save()

# %%
# or load already saved
results = ResultsWrapper(subset.iloc[:1, :], tables=None, col_in='data')
results.load()

# %%
# get metric values
evaluation = results.calculate_metrics(col_gold='gold')
display(evaluation)
#evaluation.to_csv('bert_trial_results.tsv', sep='\t')
# Out:
#                                                     MAP@15-bert_hyper  ...  MRR@15-ft+bert_cohypo_iter
# <target> is a [MASK].                                             0.0  ...                         0.0
# a <target> is a [MASK].                                           0.0  ...                         0.0
# [MASK], such as <target>.                                         0.0  ...                         0.0
# [MASK], such as a <target>.                                       0.0  ...                         0.0
# a [MASK], such as <target>.                                       0.0  ...                         0.0
# a [MASK], such as a <target>.                                     0.0  ...                         0.0
# <target> is a type of [MASK].                                     0.0  ...                         0.0
# a <target> is a type of [MASK].                                   0.0  ...                         0.0
# My favorite [MASK] is <target>.                                   0.0  ...                         0.0
# My favorite [MASK] is a <target>.                                 0.0  ...                         0.0
# <target> or some other [MASK].                                    0.0  ...                         0.0
# a <target> or some other [MASK].                                  0.0  ...                         0.0
# <target> or any other [MASK].                                     0.0  ...                         0.0
# a <target> or any other [MASK].                                   0.0  ...                         0.0
# <target> and any other [MASK].                                    0.0  ...                         0.0
# a <target> and any other [MASK].                                  0.0  ...                         0.0
# My favorite [MASK] is either <target> or <cohypo>.                0.0  ...                         0.0
# My favorite [MASK] is either a <target> or a <c...                0.0  ...                         0.0
# <target> is a [MASK]. So is <cohypo>.                             0.0  ...                         0.0
# a <target> is a [MASK]. So is a <cohypo>.                         0.0  ...                         0.0
#
# [20 rows x 12 columns]
